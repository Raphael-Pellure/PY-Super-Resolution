# %%
# %pip install torchmetrics
# %pip install rasterio
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# lancer .py %run path/to/script.py --epochs 50 --lr 1e-3
# %run prepare_data.py
# Out:
# ---------------------------------------------------------------------------
# CPLE_AppDefinedError                      Traceback (most recent call last)
# CPLE_AppDefinedError: TIFFReadEncodedStrip:Read error at scanline 4294967295; got 19360 bytes, expected 21960
#
# The above exception was the direct cause of the following exception:
#
# CPLE_AppDefinedError                      Traceback (most recent call last)
# CPLE_AppDefinedError: TIFFReadEncodedStrip() failed.
#
# The above exception was the direct cause of the following exception:
#
# CPLE_AppDefinedError                      Traceback (most recent call last)
# File rasterio/_io.pyx:969, in rasterio._io.DatasetReaderBase._read()
#
# File rasterio/_io.pyx:199, in rasterio._io.io_multi_band()
#
# File rasterio/_io.pyx:205, in rasterio._io.io_multi_band()
#
# File rasterio/_err.pyx:325, in rasterio._err.StackChecker.exc_wrap_int()
#
# ...

# %%
# %run reconstruct_image.py
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# File ~/work/PY-Super-Resolution/reconstruct_image.py:7
#       4 import rasterio as rio
#       6 # Load torch tensor
# ----> 7 Xs = torch.load("tensor_b8a_us.pt")
#       8 patch_size_h = Xs.shape[1]
#       9 patch_size_w = Xs.shape[2]
#
# File /opt/python/lib/python3.13/site-packages/torch/serialization.py:1491, in load(f, map_location, pickle_module, weights_only, mmap, **pickle_load_args)
#    1489 orig_position = opened_file.tell()
#    1490 overall_storage = None
# -> 1491 with _open_zipfile_reader(opened_file) as opened_zipfile:
#    1492     if _is_torchscript_zip(opened_zipfile):
#    1493         warnings.warn(
#    1494             "'torch.load' received a zip file that looks like a TorchScript archive"
#    1495             " dispatching to 'torch.jit.load' (call 'torch.jit.load' directly to"
# ...

# %%
import torch

X = torch.load(
    "tensor_b8_ds.pt"
)
Y = torch.load(
    "tensor_b8.pt"
)
      
dataset = torch.utils.data.dataset.TensorDataset(X.unsqueeze(1), Y.unsqueeze(1))
train_dataset, valid_dataset, test_dataset = torch.utils.data.dataset.random_split(
    dataset, [0.7, 0.1, 0.2]
)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[11], line 3
#       1 import torch
# ----> 3 X = torch.load(
#       4     "tensor_b8_ds.pt"
#       5 )
#       6 Y = torch.load(
#       7     "tensor_b8.pt"
#       8 )
#      10 dataset = torch.utils.data.dataset.TensorDataset(X.unsqueeze(1), Y.unsqueeze(1))
#
# File /opt/python/lib/python3.13/site-packages/torch/serialization.py:1491, in load(f, map_location, pickle_module, weights_only, mmap, **pickle_load_args)
#    1489 orig_position = opened_file.tell()
#    1490 overall_storage = None
# -> 1491 with _open_zipfile_reader(opened_file) as opened_zipfile:
#    1492     if _is_torchscript_zip(opened_zipfile):
#    1493         warnings.warn(
#    1494             "'torch.load' received a zip file that looks like a TorchScript archive"
# ...

# %%
print("X:", X.shape, X.dtype, X.min().item(), X.max().item())
print("Y:", Y.shape, Y.dtype, Y.min().item(), Y.max().item())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 print("X:", X.shape, X.dtype, X.min().item(), X.max().item())
#       2 print("Y:", Y.shape, Y.dtype, Y.min().item(), Y.max().item())
#
# NameError: name 'X' is not defined

# %%
import torch.nn.functional as F
from torchmetrics.image import PeakSignalNoiseRatio, StructuralSimilarityIndexMeasure

X_up = F.interpolate(X.unsqueeze(1), scale_factor=2, mode="bicubic", align_corners=False)


psnr = PeakSignalNoiseRatio(data_range=1.0)
ssim = StructuralSimilarityIndexMeasure(data_range=1.0)


print("Bicubic PSNR:", psnr(X_up, Y.unsqueeze(1)).item(), "SSIM:", ssim(X_up, Y.unsqueeze(1)).item())
